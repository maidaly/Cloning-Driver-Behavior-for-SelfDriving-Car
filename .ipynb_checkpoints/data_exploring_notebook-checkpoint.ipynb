# %%
import pandas as pd 
import numpy as np
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import os
from utils import preprocess, random_flip, random_shadow, random_brightness, random_translate
plt.style.use('ggplot')
# %matplotlib inline

# %%
data_df = pd.read_csv(os.path.join('data', 'driving_log.csv'), names=['center', 'left', 'right', 'steering', 'throttle', 'reverse', 'speed'])

# %%
print ("driving_log.csv")
data_df
# Out:
# driving_log.csv
#                                                  center  \
# 0     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 1     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 2     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 3     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 4     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 5     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 6     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 7     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 8     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9     E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 10    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 11    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 12    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 13    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 14    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 15    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 16    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 17    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 18    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 19    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 20    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 21    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 22    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 23    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 24    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 25    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 26    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 27    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 28    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 29    E:\self-driving-car-sim\IMG\center_2018_09_27_...
# ...                                                 ...
# 9039  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9040  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9041  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9042  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9043  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9044  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9045  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9046  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9047  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9048  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9049  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9050  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9051  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9052  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9053  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9054  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9055  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9056  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9057  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9058  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9059  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9060  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9061  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9062  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9063  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9064  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9065  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9066  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9067  E:\self-driving-car-sim\IMG\center_2018_09_27_...
# 9068  E:\self-driving-car-sim\IMG\center_2018_09_27_...
#
#                                                    left  \
# 0     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 1     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 2     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 3     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 4     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 5     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 6     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 7     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 8     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 9     E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 10    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 11    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 12    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 13    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 14    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 15    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 16    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 17    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 18    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 19    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 20    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 21    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 22    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 23    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 24    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 25    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 26    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 27    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 28    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# 29    E:\self-driving-car-sim\IMG\left_2018_09_27_21...
# ...                                                 ...
# 9039  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9040  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9041  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9042  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9043  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9044  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9045  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9046  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9047  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9048  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9049  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9050  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9051  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9052  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9053  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9054  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9055  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9056  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9057  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9058  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9059  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9060  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9061  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9062  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9063  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9064  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9065  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9066  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9067  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
# 9068  E:\self-driving-car-sim\IMG\left_2018_09_27_22...
#
#                                                   right  steering  throttle  \
# 0     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 1     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 2     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 3     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 4     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 5     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 6     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 7     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 8     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9     E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 10    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 11    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 12    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 13    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 14    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 15    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 16    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 17    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 18    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 19    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.163516
# 20    E:\self-driving-car-sim\IMG\right_2018_09_27_2...     -0.20  0.458464
# 21    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.148322
# 22    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 23    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 24    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 25    E:\self-driving-car-sim\IMG\right_2018_09_27_2...     -0.15  0.000000
# 26    E:\self-driving-car-sim\IMG\right_2018_09_27_2...     -0.35  0.160169
# 27    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 28    E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 29    E:\self-driving-car-sim\IMG\right_2018_09_27_2...     -0.25  0.267429
# ...                                                 ...       ...       ...
# 9039  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9040  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9041  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9042  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9043  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9044  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9045  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9046  E:\self-driving-car-sim\IMG\right_2018_09_27_2...     -0.20  0.000000
# 9047  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9048  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9049  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9050  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9051  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9052  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9053  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9054  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9055  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9056  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9057  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9058  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9059  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9060  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9061  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9062  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9063  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9064  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9065  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9066  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9067  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
# 9068  E:\self-driving-car-sim\IMG\right_2018_09_27_2...      0.00  0.000000
#
#       reverse         speed
# 0           0  1.218441e-05
# 1           0  3.074945e-06
# 2           0  8.765182e-06
# 3           0  9.717940e-06
# 4           0  1.284428e-05
# 5           0  1.533286e-05
# 6           0  1.630438e-05
# 7           0  4.029117e-06
# 8           0  6.222742e-06
# 9           0  1.274476e-05
# 10          0  3.100163e-07
# 11          0  6.331391e-06
# 12          0  6.892256e-06
# 13          0  2.587731e-05
# 14          0  1.200615e-05
# 15          0  8.474471e-06
# 16          0  1.833111e-05
# 17          0  4.881882e-06
# 18          0  1.250816e-05
# 19          0  1.117592e-01
# 20          0  4.633862e-01
# 21          0  8.284648e-01
# 22          0  7.960567e-01
# 23          0  7.880044e-01
# 24          0  7.801061e-01
# 25          0  7.700349e-01
# 26          0  8.326935e-01
# 27          0  8.282093e-01
# 28          0  8.181947e-01
# 29          0  1.060378e+00
# ...       ...           ...
# 9039        0  1.316365e+01
# 9040        0  1.312097e+01
# 9041        0  1.287313e+01
# 9042        0  1.276663e+01
# 9043        0  1.260853e+01
# 9044        0  1.245302e+01
# 9045        0  1.232266e+01
# 9046        0  1.220803e+01
# 9047        0  1.205407e+01
# 9048        0  1.195094e+01
# 9049        0  1.177566e+01
# 9050        0  1.167372e+01
# 9051        0  1.156913e+01
# 9052        0  1.146443e+01
# 9053        0  1.128754e+01
# 9054        0  1.119340e+01
# 9055        0  1.114028e+01
# 9056        0  1.100626e+01
# 9057        0  1.087391e+01
# 9058        0  1.074310e+01
# 9059        0  1.065676e+01
# 9060        0  1.054981e+01
# 9061        0  1.040189e+01
# 9062        0  1.029750e+01
# 9063        0  1.017359e+01
# 9064        0  1.005117e+01
# 9065        0  9.930225e+00
# 9066        0  9.810738e+00
# 9067        0  9.712263e+00
# 9068        0  9.595399e+00
#
# [9069 rows x 7 columns]

# %%
steering_angle = data_df["steering"].values
data_df["steering"].describe()
# Out:
# count    9069.000000
# mean       -0.032772
# std         0.178340
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: steering, dtype: float64

# %% [markdown]
# **Steering angle distrbution**

# %%
fig = plt.figure(figsize=(12,6))
plt.hist(steering_angle,alpha=0.60,bins=25,ec='w')
plt.ylabel("Frequancy")
plt.title('Histogram of Steering angle')
# Out:
# Text(0.5,1,'Histogram of Steering angle')

# %% [markdown]
# The high frequancy of 0 can lead to bias the model to 0. we can avoid this by making copies of non zeros and try to apply some Augmentation function to have better distrbution.

# %% [markdown]
# **Preprocessing**
#
# In Preprocessing 3 functions are applied to the image ( crop, resize, rgb2yuv). The crop function removes unnecessary parts from the image like the sky and the front part of the car as they hold no information. The resize function resizes the image to the input shape used by the network model (66, 200). The rgb2yuv converts the image from RGB to YUV (This is what the NVIDIA model does)

# %%
images= data_df[['left','center', 'right']].values

# %%
list_of_titles = ['left','center', 'right']
list_of_images = images[100]
fig = plt.figure(figsize=(20,7))
column = 1
print("Sample af training images and the crosponding preprocessing")
for i in range(len(list_of_images)):
        plt.subplot(2, 3, column)
        image = np.array(plt.imread(list_of_images[i]))
        plt.imshow(image)
        plt.imsave("original_image_"+list_of_titles[i]+".png",image)
        plt.axis('off')
        plt.title("Original image" +"\n"+list_of_titles[i])
        plt.subplot(2, 3, column+3)
        plt.imshow(preprocess(image))
        plt.imsave("preprocess_image_"+list_of_titles[i]+".png",preprocess(image))
        plt.axis('off')
        plt.title("Preprocessing image" +"\n"+list_of_titles[i])
        column += 1
# Out:
# Sample af training images and the crosponding preprocessing

# %% [markdown]
#  ### Image Augmentation
#
# The image augmentation is done by applaying 4 functions randomly to the images the 4 functions are:
#
# ***random_flip*** : Flipping the copies of image horizontally, and negating the steering angles. this function tries to add some                     balance to the steering_angle distribution.
#
# ***random_translate*** : Randomly translate image with steering angle adjustment (0.002 per pixel shift).
#
# ***random_shadow*** : Randomly added shadows to fit diffrent conditions.
#
# ***random_brightness*** : Randomly change brightness to fit diffrent conditions (lighter or darker).

# %%
list_of_titles = ['left','center', 'right']
list_of_images = images[100]
steering = steering_angle[100]
fig = plt.figure(figsize=(20,25))
column = 1
print("Sample af augmentation functions and the crosponding preprocessing")
for i in range(len(list_of_images)):
        plt.subplot(6, 3, column)
        image = np.array(plt.imread(list_of_images[i]))
        plt.imshow(image)
        plt.axis('off')
        plt.title("Original image , Steering angle: {}".format(np.round(steering,3)) +"\n"+list_of_titles[i])
        column += 1
        
# flip image        
for i in range(len(list_of_images)):
        plt.subplot(6, 3, column)
        image = np.array(plt.imread(list_of_images[i]))
        processed_image, new_steering = random_flip(image,steering, force_flip =True)
        plt.imshow(processed_image)
        plt.axis('off')
        plt.title("fliping image , New steering angle: {}".format(np.round(new_steering,3)) +"\n"+list_of_titles[i])
        plt.imsave("flip_"+list_of_titles[i]+".png",processed_image)        
        column += 1

# translate image        
for i in range(len(list_of_images)):
        plt.subplot(6, 3, column)
        image = np.array(plt.imread(list_of_images[i]))
        processed_image, new_steering = random_translate(image,steering, range_x= 50, range_y= 50)
        plt.imshow(processed_image)
        plt.axis('off')
        plt.title("translating image , New steering angle: {}".format(np.round(new_steering,3)) +"\n"+list_of_titles[i])
        plt.imsave("translate_"+list_of_titles[i]+".png",processed_image)
        column += 1

# add random_shadow         
for i in range(len(list_of_images)):
        plt.subplot(6, 3, column)
        image = np.array(plt.imread(list_of_images[i]))
        processed_image = random_shadow(image)
        plt.imshow(processed_image)
        plt.axis('off')
        plt.title("shadowing image , Steering angle: {}".format(np.round(steering,3)) +"\n"+list_of_titles[i])
        plt.imsave("shadow_"+list_of_titles[i]+".png",processed_image)
        column += 1
        
# add random_brightness
for i in range(len(list_of_images)):
        plt.subplot(6, 3, column)
        image = np.array(plt.imread(list_of_images[i]))
        processed_image = random_brightness(image)
        plt.imshow(processed_image)
        plt.axis('off')
        plt.title("random_brightnes image , Steering angle: {}".format(np.round(steering,3)) +"\n"+list_of_titles[i])
        plt.imsave("brightness_"+list_of_titles[i]+".png",processed_image)
        column += 1
# Out:
# Sample af augmentation functions and the crosponding preprocessing

# %% [markdown]
# ### Model architecture
# ![](assets/cnn-architecture.png)

# %% [markdown]
# ## Result
#
# By using autonomous mode in the simulator, the model tested on the training track.
# The figure below shows how testing work.
#
#
# ![alt text](https://cdn-images-1.medium.com/max/1440/1*nlusa_fC5BnsgnWPFnov7Q.tiff "Logo Title Text 1")

# %%
print ("The video below shows the model test .")
import IPython.display as display
display.YouTubeVideo("JI-xxoZxkRU", width=500, height=300)
# Out:
# The video below shows the model test .
